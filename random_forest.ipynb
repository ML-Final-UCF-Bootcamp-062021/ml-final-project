# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree

# %%
df = pd.read_csv("usda_data.csv")
df
# Out:
#        CensusTract  Urban  Pop2010  OHU2010  LILATracts_1And10  \
# 0       1001020100      1     1912      693                  0
# 1       1001020200      1     2170      743                  1
# 2       1001020300      1     3373     1256                  0
# 3       1001020400      1     4386     1722                  0
# 4       1001020500      1    10766     4082                  0
# ...            ...    ...      ...      ...                ...
# 52537  56041975400      0     6852     2632                  0
# 52538  56043000200      0     3326     1317                  0
# 52539  56043000302      1     2542     1021                  0
# 52540  56045951100      0     3314     1322                  0
# 52541  56045951300      1     3894     1699                  0
#
#        LILATracts_Vehicle  HUNVFlag  LowIncomeTracts  PovertyRate  \
# 0                       0         0                0         11.3
# 1                       0         0                1         17.9
# 2                       0         0                0         15.0
# 3                       0         0                0          2.8
# 4                       0         1                0         15.2
# ...                   ...       ...              ...          ...
# 52537                   1         1                1         17.3
# 52538                   0         0                0          9.7
# 52539                   0         0                0         16.3
# 52540                   0         0                0         17.5
# 52541                   0         0                0         17.3
#
#        MedianFamilyIncome   ...  lasnap1share  TractLOWI  TractWhite  \
# 0              $81,250.00   ...         13.22      455.0      1622.0
# 1              $49,000.00   ...         12.95      802.0       888.0
# 2              $62,609.00   ...          5.87     1306.0      2576.0
# 3              $70,607.00   ...          1.76      922.0      4086.0
# 4              $96,334.00   ...          2.04     2242.0      8666.0
# ...                    ...  ...           ...        ...         ...
# 52537          $57,248.00   ...          3.39     2273.0      6160.0
# 52538          $67,254.00   ...          3.82      765.0      3106.0
# 52539          $69,605.00   ...          0.45      789.0      2312.0
# 52540          $74,500.00   ...          1.59      955.0      3179.0
# 52541          $76,838.00   ...          2.20     1095.0      3706.0
#
#        TractBlack  TractAsian  TractNHOPI  TractAIAN  TractOMultir  \
# 0           217.0        14.0         0.0       14.0          45.0
# 1          1217.0         5.0         0.0        5.0          55.0
# 2           647.0        17.0         5.0       11.0         117.0
# 3           193.0        18.0         4.0       11.0          74.0
# 4          1437.0       296.0         9.0       48.0         310.0
# ...           ...         ...         ...        ...           ...
# 52537        20.0        19.0         2.0       67.0         584.0
# 52538         6.0        15.0         0.0       27.0         172.0
# 52539        11.0        10.0         1.0       26.0         182.0
# 52540        15.0        10.0         1.0       47.0          62.0
# 52541         6.0        10.0         2.0       44.0         126.0
#
#        TractHispanic  TractHUNV
# 0               44.0        6.0
# 1               75.0       89.0
# 2               87.0       99.0
# 3               85.0       21.0
# 4              355.0      230.0
# ...              ...        ...
# 52537          871.0      124.0
# 52538          309.0       61.0
# 52539          407.0       23.0
# 52540           91.0       47.0
# 52541          125.0       34.0
#
# [52542 rows x 43 columns]

# %%
target = df["LATracts1"]

# %%
data = df.drop("LATracts1", axis=1)
feature_names = data.columns
data.head()
# Out:
#    CensusTract  Urban  Pop2010  OHU2010  LILATracts_1And10  \
# 0   1001020100      1     1912      693                  0
# 1   1001020200      1     2170      743                  1
# 2   1001020300      1     3373     1256                  0
# 3   1001020400      1     4386     1722                  0
# 4   1001020500      1    10766     4082                  0
#
#    LILATracts_Vehicle  HUNVFlag  LowIncomeTracts  PovertyRate  \
# 0                   0         0                0         11.3
# 1                   0         0                1         17.9
# 2                   0         0                0         15.0
# 3                   0         0                0          2.8
# 4                   0         1                0         15.2
#
#    MedianFamilyIncome   ...  lasnap1share  TractLOWI  TractWhite  TractBlack  \
# 0          $81,250.00   ...         13.22      455.0      1622.0       217.0
# 1          $49,000.00   ...         12.95      802.0       888.0      1217.0
# 2          $62,609.00   ...          5.87     1306.0      2576.0       647.0
# 3          $70,607.00   ...          1.76      922.0      4086.0       193.0
# 4          $96,334.00   ...          2.04     2242.0      8666.0      1437.0
#
#    TractAsian  TractNHOPI  TractAIAN  TractOMultir  TractHispanic  TractHUNV
# 0        14.0         0.0       14.0          45.0           44.0        6.0
# 1         5.0         0.0        5.0          55.0           75.0       89.0
# 2        17.0         5.0       11.0         117.0           87.0       99.0
# 3        18.0         4.0       11.0          74.0           85.0       21.0
# 4       296.0         9.0       48.0         310.0          355.0      230.0
#
# [5 rows x 42 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-919dfd680ef1> in <module>
#       1 clf = tree.DecisionTreeClassifier()
# ----> 2 clf = clf.fit(X_train, y_train)
#       3 clf.score(X_test, y_test)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     892             sample_weight=sample_weight,
#     893             check_input=check_input,
# --> 894             X_idx_sorted=X_idx_sorted)
#     895         return self
#     896
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
# --> 158                                                             check_y_params))
#     159             if issparse(X):
#     160                 X.sort_indices()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     427                 # :(
#     428                 check_X_params, check_y_params = validate_separately
# --> 429                 X = check_array(X, **check_X_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: ' $26,389.00 '

# %%
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
