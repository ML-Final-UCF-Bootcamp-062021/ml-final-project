# %%
import pandas as pd

# %%
data = pd.read_csv('Gregory/usda_data-5-27.csv')

# %%
df = pd.DataFrame(data)
sample_df = df.head(10)
sample_df
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
# 5   1001020600  Alabama  Autauga County      1     3668     1311
# 6   1001020700  Alabama  Autauga County      1     2891     1188
# 7   1001020801  Alabama  Autauga County      0     3081     1074
# 8   1001020802  Alabama  Autauga County      0    10435     3694
# 9   1001020900  Alabama  Autauga County      0     5675     2067
#
#    LILATracts_1And10  LILATracts_Vehicle  HUNVFlag  LowIncomeTracts  ...  \
# 0                  0                   0         0                0  ...
# 1                  1                   0         0                1  ...
# ...

# %%
from IPython.display import HTML

# %%
result = sample_df.to_html()

# %%
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CensusTract</th>
#       <th>State</th>
#       <th>County</th>
#       <th>Urban</th>
#       <th>Pop2010</th>
#       <th>OHU2010</th>
#       <th>LILATracts_1And10</th>
#       <th>LILATracts_Vehicle</th>
#       <th>HUNVFlag</th>
#       <th>LowIncomeTracts</th>
#       <th>PovertyRate</th>
#       <th>MedianFamilyIncome</th>
#       <th>LA1and10</th>
#       <th>LATracts1</th>
#       <th>lapop1</th>
#       <th>lapop1share</th>
#       <th>lalowi1</th>
#       <th>lalowi1share</th>
#       <th>lawhite1</th>
#       <th>lawhite1share</th>
#       <th>lablack1</th>
#       <th>lablack1share</th>
#       <th>laasian1</th>
#       <th>laasian1share</th>
#       <th>lanhopi1</th>
#       <th>lanhopi1share</th>
#       <th>laaian1</th>
#       <th>laaian1share</th>
#       <th>laomultir1</th>
#       <th>laomultir1share</th>
#       <th>lahisp1</th>
# ...

# %%
# write html to file
text_file = open("table.html", "w")
text_file.write(result)
text_file.close()
